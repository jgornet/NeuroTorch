# %%
# Import modules
from __future__ import print_function
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
tf.enable_eager_execution()

# Notebook auto reloads code.
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # NeuroTorch Tutorial
#
# **NeuroTorch** is a framework for reconstructing neuronal morphology from
# optical microscopy images. It interfaces PyTorch with different
# automated neuron tracing algorithms for fast, accurate, scalable
# neuronal reconstructions. It uses deep learning to generate an initial
# segmentation of neurons in optical microscopy images. This
# segmentation is then traced using various automated neuron tracing
# algorithms to convert the segmentation into an SWC file—the most
# common neuronal morphology file format. NeuroTorch is designed with
# scalability in mind and can handle teravoxel-sized images.
#
# This IPython notebook will outline a brief tutorial for using NeuroTorch
# to train and predict on image volume datasets.

# %% [markdown]
# ## Creating image datasets
#
# One of NeuroTorch’s key features is its dynamic approach to volumetric datasets, which allows it to handle teravoxel-sized images without worrying about memory concerns and efficiency. Everything is loaded just-in-time based on when it is needed or expected to be needed. To load an image dataset, we need
# to specify the voxel coordinates of each image file as shown in files `inputs_spec.json` and `labels_spec.json`.
#
# ### `inputs_spec.json`
#
# ```json
# [
#     {
# 	"filename" : "inputs.tif",
# 	"bounding_box" : [[0, 0, 0], [1024, 512, 50]]
#     },
#     {
# 	"filename" : "inputs.tif",
# 	"bounding_box" : [[0, 0, 50], [1024, 512, 100]]
#     }
# ]
#
# ```
#
# ### `labels_spec.json`
#
# ```json
# [
#     {
# 	"filename" : "labels.tif",
# 	"bounding_box" : [[0, 0, 0], [1024, 512, 50]]
#     },
#     {
# 	"filename" : "labels.tif",
# 	"bounding_box" : [[0, 0, 50], [1024, 512, 100]]
#     }
# ]
# ```

# %% [markdown]
# ## Loading image datasets
#
# Now that the image datasets for the inputs and labels have been specified,
# these datasets can be loaded with NeuroTorch.

# %%
from neurotorch.datasets.specification import JsonSpec
import os

IMAGE_PATH = '/data/gornet/annotated-neurons'

json_spec = JsonSpec() # Initialize the JSON specification

# Create a dataset containing the inputs
inputs = json_spec.open(os.path.join(IMAGE_PATH,
                                     "input_spec.json")) 

# Create a dataset containing the labels
labels = json_spec.open(os.path.join(IMAGE_PATH,
                                     "label_spec.json"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-607ad00087ba> in <module>
#       8 # Create a dataset containing the inputs
#       9 inputs = json_spec.open(os.path.join(IMAGE_PATH,
# ---> 10                                      "input_spec.json"))
#      11
#      12 # Create a dataset containing the labels
#
# ~/Downloads/NeuroTorch/neurotorch/datasets/specification.py in open(self, spec_filename)
#      73         :return: The pooled volume of the volume dataset
#      74         """
# ---> 75         spec = self.parse(spec_filename)
#      76
#      77         cwd = os.getcwd()
#
# ~/Downloads/NeuroTorch/neurotorch/datasets/specification.py in parse(self, spec_filename)
#     107             raise ValueError(error_string)
#     108
# --> 109         with open(spec_filename, 'r') as f:
#     110             spec = json.load(f)
#     111
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/gornet/annotated-neurons/input_spec.json'

# %%
from neurotorch.datasets.specification import JsonSpec
import os

IMAGE_PATH = './tests/images/'

json_spec = JsonSpec() # Initialize the JSON specification

# Create a dataset containing the inputs
inputs = json_spec.open(os.path.join(IMAGE_PATH,
                                     "inputs_spec.json")) 

# Create a dataset containing the labels
labels = json_spec.open(os.path.join(IMAGE_PATH,
                                     "labels_spec.json"))

# %%
from neurotorch.datasets.dataset import AlignedVolume

volume = AlignedVolume([inputs, labels])

# %% [markdown]
# ## Training with the image datasets
#
# To train a neural network using these image datasets, load the
# neural network architecture and initialize a `Trainer`. To save
# training checkpoints, add a `CheckpointWriter` to the `Trainer` object.
# Lastly, call the `Trainer` object to run training.

# %%
from neurotorch.core.trainer import Trainer
from neurotorch.training.logging import LossWriter, ImageWriter
from neurotorch.training.checkpoint import CheckpointWriter
from neurotorch.nets.RSLSTMUnet import RSUNet

net = RSUNet([4, 16], [128], (16, 64, 64)) # Initialize the U-Net architecture

# Setup the trainer
trainer = Trainer(net, volume, max_epochs=10,
                  gpu_device=1)

# Setup the trainer the add a checkpoint every 500 epochs
trainer = CheckpointWriter(trainer, checkpoint_dir='BMEN4000',
                           checkpoint_period=2000)
trainer = LossWriter(trainer, ".", "BMEN4000")
trainer = ImageWriter(trainer, ".", "BMEN4000")

trainer.run_training()
# Out:
# Opening /home/jamesgornet/Downloads/NeuroTorch/tests/images/labels.tif
# Opening /home/jamesgornet/Downloads/NeuroTorch/tests/images/labels.tif
# Opening /home/jamesgornet/Downloads/NeuroTorch/tests/images/inputs.tif
# Opening /home/jamesgornet/Downloads/NeuroTorch/tests/images/inputs.tif
# Iteration: 1
# WARNING:tensorflow:From /home/jamesgornet/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:642: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/jamesgornet/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/ops/losses/losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 10 Epoch 1/10  Loss: 1.9436 Accuracy: 6.51
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 20 Epoch 1/10  Loss: 0.7016 Accuracy: 5.08
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Iteration: 30
# Iteration: 30 Epoch 1/10  Loss: 0.6669 Accuracy: 0.41
# Iteration: 31
# Iteration: 32
# Iteration: 33
# Iteration: 34
# Iteration: 35
# Iteration: 36
# Iteration: 37
# Iteration: 38
# Iteration: 39
# Iteration: 40
# Iteration: 40 Epoch 1/10  Loss: 0.6551 Accuracy: 0.00
# Iteration: 41
# Iteration: 42
# Iteration: 43
# Iteration: 44
# Iteration: 45
# Iteration: 46
# Iteration: 47
# Iteration: 48
# Iteration: 49
# Iteration: 50
# Iteration: 50 Epoch 1/10  Loss: 0.6435 Accuracy: 0.00
# Iteration: 51
# Iteration: 52
# Iteration: 53
# Iteration: 54
# Iteration: 55
# Iteration: 56
# Iteration: 57
# Iteration: 58
# Iteration: 59
# Iteration: 60
# Iteration: 60 Epoch 1/10  Loss: 0.6321 Accuracy: 0.00
# Iteration: 61
# Iteration: 62
# Iteration: 63
# Iteration: 64
# Iteration: 65
# Iteration: 66
# Iteration: 67
# Iteration: 68
# Iteration: 69
# Iteration: 70
# Iteration: 70 Epoch 1/10  Loss: 0.6210 Accuracy: 0.00
# Iteration: 71
# Iteration: 72
# Iteration: 73
# Iteration: 74
# Iteration: 75
# Iteration: 76
# Iteration: 77
# Iteration: 78
# Iteration: 79
# Iteration: 80
# Iteration: 80 Epoch 1/10  Loss: 0.6101 Accuracy: 0.00
# Iteration: 81
# Iteration: 82
# Iteration: 83
# Iteration: 84
# Iteration: 85
# Iteration: 86
# Iteration: 87
# Iteration: 88
# Iteration: 89
# Iteration: 90
# Iteration: 90 Epoch 1/10  Loss: 0.5995 Accuracy: 0.00
# Iteration: 91
# Iteration: 92
# Iteration: 93
# Iteration: 94
# Iteration: 95
# Iteration: 96
# Iteration: 97
# Iteration: 98
# Iteration: 99
# Iteration: 100
# Iteration: 100 Epoch 1/10  Loss: 0.5891 Accuracy: 0.00
# Iteration: 101
# Iteration: 102
# Iteration: 103
# Iteration: 104
# Iteration: 105
# Iteration: 106
# Iteration: 107
# Iteration: 108
# Iteration: 109
# Iteration: 110
# Iteration: 110 Epoch 1/10  Loss: 0.5790 Accuracy: 0.00
# Iteration: 111
# Iteration: 112
# Iteration: 113
# Iteration: 114
# Iteration: 115
# Iteration: 116
# Iteration: 117
# Iteration: 118
# Iteration: 119
# Iteration: 120
# Iteration: 120 Epoch 1/10  Loss: 0.5691 Accuracy: 0.00
# Iteration: 121
# Iteration: 122
# Iteration: 123
# Iteration: 124
# Iteration: 125
# Iteration: 126
# Iteration: 127
# Iteration: 128
# Iteration: 129
# Iteration: 130
# Iteration: 130 Epoch 1/10  Loss: 0.5595 Accuracy: 0.00
# Iteration: 131
# Iteration: 132
# Iteration: 133
# Iteration: 134
# Iteration: 135
# Iteration: 136
Epoch 2/10  Loss: 0.2470 Accuracy: 0.00
# Iteration: 3171
# Iteration: 3172
# Iteration: 3173
# Iteration: 3174
# Iteration: 3175
# Iteration: 3176
# Iteration: 3177
# Iteration: 3178
# Iteration: 3179
# Iteration: 3180
# Iteration: 3180 Epoch 2/10  Loss: 0.2470 Accuracy: 0.00
# Iteration: 3181
# Iteration: 3182
# Iteration: 3183
# Iteration: 3184
# Iteration: 3185
# Iteration: 3186
# Iteration: 3187
# Iteration: 3188
# Iteration: 3189
# Iteration: 3190
# Iteration: 3190 Epoch 2/10  Loss: 0.2471 Accuracy: 0.00
# Iteration: 3191
# Iteration: 3192
# Iteration: 3193
# Iteration: 3194
# Iteration: 3195
# Iteration: 3196
# Iteration: 3197
# Iteration: 3198
# Iteration: 3199
# Iteration: 3200
# Iteration: 3200 Epoch 2/10  Loss: 0.2472 Accuracy: 0.00
# Iteration: 3201
# Iteration: 3202
# Iteration: 3203
# Iteration: 3204
# Iteration: 3205
# Iteration: 3206
# Iteration: 3207
# Iteration: 3208
# Iteration: 3209
# Iteration: 3210
# Iteration: 3210 Epoch 2/10  Loss: 0.2472 Accuracy: 0.00
# Iteration: 3211
# Iteration: 3212
# Iteration: 3213
# Iteration: 3214
# Iteration: 3215
# Iteration: 3216
# Iteration: 3217
# Iteration: 3218
# Iteration: 3219
# Iteration: 3220
# Iteration: 3220 Epoch 2/10  Loss: 0.2472 Accuracy: 0.00
# Iteration: 3221
# Iteration: 3222
# Iteration: 3223
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv3d(input, filter, strides, padding, data_format, dilations, name)
#    1404         "padding", padding, "data_format", data_format, "dilations",
# -> 1405         dilations)
#    1406       return _result
#
# _FallbackException: Expecting int64_t value for attr strides, got numpy.int32
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-84eb4bea4b46> in <module>
#      16 trainer = ImageWriter(trainer, ".", "BMEN")
#      17
# ---> 18 trainer.run_training()
#
# ~/Downloads/NeuroTorch/neurotorch/core/trainer.py in run_training(self)
#     189
#     190                 print("Iteration: {}".format(num_iter))
# --> 191                 self.run_epoch(sample_batch)
#     192
#     193                 if num_iter % 10 == 0:
#
# ~/Downloads/NeuroTorch/neurotorch/training/logging.py in run_epoch(self, sample_batch)
#     186         :param sample_batch: A batch of input/label samples for training
#     187         """
# --> 188         loss = super().run_epoch(sample_batch)
#     189
#     190         self.iteration += 1
#
# ~/Downloads/NeuroTorch/neurotorch/core/trainer.py in run_epoch(self, sample_batch)
#     152
#     153     def run_epoch(self, sample_batch):
# --> 154         return self._trainer.run_epoch(sample_batch)
#     155
#     156     def evaluate(self, batch):
#
# ~/Downloads/NeuroTorch/neurotorch/training/logging.py in run_epoch(self, sample_batch)
#      63         """
#      64         start = time.time()
# ---> 65         loss = super().run_epoch(sample_batch)
#      66         end = time.time()
#      67
#
# ~/Downloads/NeuroTorch/neurotorch/core/trainer.py in run_epoch(self, sample_batch)
#     152
#     153     def run_epoch(self, sample_batch):
# --> 154         return self._trainer.run_epoch(sample_batch)
#     155
#     156     def evaluate(self, batch):
#
# ~/Downloads/NeuroTorch/neurotorch/training/checkpoint.py in run_epoch(self, sample_batch)
#      35         :param sample_batch: A batch of input/label samples for training
#      36         """
# ---> 37         loss = super().run_epoch(sample_batch)
#      38
#      39         if self.iteration % self.checkpoint_period == 0:
#
# ~/Downloads/NeuroTorch/neurotorch/core/trainer.py in run_epoch(self, sample_batch)
#     152
#     153     def run_epoch(self, sample_batch):
# --> 154         return self._trainer.run_epoch(sample_batch)
#     155
#     156     def evaluate(self, batch):
#
# ~/Downloads/NeuroTorch/neurotorch/core/trainer.py in run_epoch(self, sample_batch)
#      58                                           dtype=tf.float32)
#      59
# ---> 60             outputs = self.net(inputs)
#      61
#      62             loss = self.criterion(labels, outputs)
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     590       else:
#     591         # Eager execution on data tensors.
# --> 592         outputs = self.call(inputs, *args, **kwargs)
#     593         self._handle_activity_regularization(inputs, outputs)
#     594         return outputs
#
# ~/Downloads/NeuroTorch/neurotorch/nets/RSLSTMUnet.py in call(self, inputs)
#     122
#     123     def call(self, inputs):
# --> 124         x = self.encoder(inputs)
#     125         feature_space = self.feature_space(x[-1])
#     126         x = self.decoder(x, feature_space)
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     590       else:
#     591         # Eager execution on data tensors.
# --> 592         outputs = self.call(inputs, *args, **kwargs)
#     593         self._handle_activity_regularization(inputs, outputs)
#     594         return outputs
#
# ~/Downloads/NeuroTorch/neurotorch/nets/RSLSTMUnet.py in call(self, inputs)
#      38         activation_map = []
#      39
# ---> 40         x = self.input_conv(inputs)
#      41         for conv_1, conv_2, conv_3 in zip(self.conv_1, self.conv_2, self.conv_3):
#      42             x1 = conv_1(x)
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     590       else:
#     591         # Eager execution on data tensors.
# --> 592         outputs = self.call(inputs, *args, **kwargs)
#     593         self._handle_activity_regularization(inputs, outputs)
#     594         return outputs
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/keras/layers/convolutional.py in call(self, inputs)
#     192
#     193   def call(self, inputs):
# --> 194     outputs = self._convolution_op(inputs, self.kernel)
#     195
#     196     if self.use_bias:
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#     964
#     965   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 966     return self.conv_op(inp, filter)
#     967
#     968
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#     589
#     590   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 591     return self.call(inp, filter)
#     592
#     593
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in __call__(self, inp, filter)
#     206         padding=self.padding,
#     207         data_format=self.data_format,
# --> 208         name=self.name)
#     209
#     210
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv3d(input, filter, strides, padding, data_format, dilations, name)
#    1409         return conv3d_eager_fallback(
#    1410             input, filter, strides=strides, padding=padding,
# -> 1411             data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#    1412       except _core._SymbolicException:
#    1413         pass  # Add nodes to the TensorFlow graph.
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv3d_eager_fallback(input, filter, strides, padding, data_format, dilations, name, ctx)
#    1479   "data_format", data_format, "dilations", dilations)
#    1480   _result = _execute.execute(b"Conv3D", 1, inputs=_inputs_flat, attrs=_attrs,
# -> 1481                              ctx=_ctx, name=name)
#    1482   _execute.record_gradient(
#    1483       "Conv3D", _inputs_flat, _attrs, _result, name)
#
# ~/.conda/envs/BMEN4000/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      59                                                op_name, inputs, attrs,
# ---> 60                                                num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Predicting using NeuroTorch
#
# Once training has completed, we can use the training checkpoints
# to predict on image datasets. We first have to
# load the neural network architecture and image volume.
# We then have to initialize a `Predictor` object and an output volume.
# Once these have been specified, we can begin prediction.

# %%
from neurotorch.nets.RSLSTMUnet import RSUNet
from neurotorch.core.predictor import Predictor
from neurotorch.datasets.filetypes import TiffVolume
from neurotorch.datasets.dataset import Array
from neurotorch.datasets.datatypes import (BoundingBox, Vector)
import numpy as np
import tifffile as tif
import os

IMAGE_PATH = 'tests/images/'

net = RSUNet([4, 16], [128], (8, 32, 32)) # Initialize the U-Net architecture

checkpoint = './checkpoints/best.ckpt-39' # Specify the checkpoint path

with TiffVolume(os.path.join(IMAGE_PATH,
                             "inputs.tif"),
                BoundingBox(Vector(0, 0, 0),
                            Vector(1024, 512, 50)),
                iteration_size=BoundingBox(Vector(0, 0, 0),
                                          Vector(32, 32, 8)),
                stride=Vector(4, 16, 16)) as inputs:
    predictor = Predictor(net, checkpoint, gpu_device=0)

    output_volume = Array(np.zeros(inputs.getBoundingBox()
                                   .getNumpyDim(), dtype=np.float32))

    predictor.run(inputs, output_volume, batch_size=16)

    tif.imsave("test_prediction.tif",
               output_volume.getArray().astype(np.float32))
# Out:
# Opening tests/images/inputs.tif
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-526961a041fe> in <module>
#      26                                    .getNumpyDim(), dtype=np.float32))
#      27
# ---> 28     predictor.run(inputs, output_volume, batch_size=16)
#      29
#      30     tif.imsave("test_prediction.tif",
#
# ~/Downloads/NeuroTorch/neurotorch/core/predictor.py in run(self, input_volume, output_volume, batch_size)
#      35             batch = [input_volume[i] for i in batch_index]
#      36
# ---> 37             self.run_batch(batch, output_volume)
#      38
#      39     def getBatchSize(self):
#
# ~/Downloads/NeuroTorch/neurotorch/core/predictor.py in run_batch(self, batch, output_volume)
#      51         data_list = self.toData(outputs, bounding_boxes)
#      52         for data in data_list:
# ---> 53             output_volume.blend(data)
#      54
#      55     def toArray(self, data):
#
# ~/Downloads/NeuroTorch/neurotorch/datasets/dataset.py in blend(self, data)
#     199         result = Data(array, data.getBoundingBox())
#     200
# --> 201         self.set(result)
#     202
#     203     def getArray(self, bounding_box: BoundingBox=None) -> np.ndarray:
#
# ~/Downloads/NeuroTorch/neurotorch/datasets/dataset.py in set(self, data)
#     185
#     186
# --> 187         self.array[z1:z2, y1:y2, x1:x2] = data_array
#     188
#     189     def blend(self, data: Data):
#
# ValueError: could not broadcast input array from shape (8,32,32) into shape (2,32,32)

# %%
with TiffVolume(os.path.join(IMAGE_PATH,
                             "inputs.tif"),
                BoundingBox(Vector(0, 0, 0),
                            Vector(1024, 512, 50))) as inputs:
    print(inputs.getArray().getArray().dtype)
    print(type(inputs[1]))
    plt.imshow(inputs.get(
    BoundingBox(Vector(0, 0, 0),
                Vector(256, 256, 40))).getArray()[25],
           cmap='gray'
          )

# %% [markdown]
# ## Displaying the prediction
#
# Predictions are output in logits form. To map this to a
# probability distribution, we need to apply a sigmoid function
# to the prediction. We can then evaluate the prediction and
# ground-truth.

# %%
# Apply sigmoid function
probability_map = 1/(1+np.exp(-output_volume.getArray()))

# Plot prediction and ground-truth
plt.subplot(2, 1, 1)
plt.title('Prediction')
plt.imshow(np.amax(output_volume.getArray(), axis=0))
plt.axis('off')

plt.subplot(2, 1, 2)
plt.title('Ground-Truth')
plt.imshow(labels.get(
    BoundingBox(Vector(0, 0, 0),
                Vector(1024, 512, 50))).getArray()[25],
           cmap='gray'
          )
plt.axis('off')

plt.show()
